# %%
import IPython.display as ipd
import librosa

test_path = "Classic Clean (Snare).wav"

ipd.Audio(test_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
